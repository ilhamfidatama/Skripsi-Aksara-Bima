# %%
from ipynb.fs.full.KNN import Klasifikasi
from ipynb.fs.full.ExportCSV import EksportNaufal

# %%
en = EksportNaufal('glcm_0_0')
data, classData = en.loadData()
tetangga = [1,3,5,7,9]
for k in tetangga:
    print('k=',k)
    knn = Klasifikasi(k)
    score, mean = knn.procced(data, classData)
    print('score:',score)
    print('mean:', mean)
# Out:
# k= 1
# 2639
# train: 0.7499052671466464 %  testing: 0.25009473285335354 %
# train: 0.7499052671466464 %  testing: 0.25009473285335354 %
# train: 0.7499052671466464 %  testing: 0.25009473285335354 %
# train: 0.7502841985600607 %  testing: 0.24971580143993938 %
# [0.6045454545454545, 0.5909090909090909, 0.6303030303030303, 0.6176024279210925]
# score: [0.6045454545454545, 0.5909090909090909, 0.6303030303030303, 0.6176024279210925]
# mean: 0.6108400009196671
# k= 3
# 2639
# train: 0.7499052671466464 %  testing: 0.25009473285335354 %
# train: 0.7499052671466464 %  testing: 0.25009473285335354 %
# train: 0.7499052671466464 %  testing: 0.25009473285335354 %
# train: 0.7502841985600607 %  testing: 0.24971580143993938 %
# [0.5015151515151515, 0.5272727272727272, 0.553030303030303, 0.5295902883156297]
# score: [0.5015151515151515, 0.5272727272727272, 0.553030303030303, 0.5295902883156297]
# mean: 0.5278521175334528
# k= 5
# 2639
# train: 0.7499052671466464 %  testing: 0.25009473285335354 %
# ...
